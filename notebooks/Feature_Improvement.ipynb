# %% [markdown]
# # Feature Improvement
#
# Various feature improvement.

# %% [markdown]
# ## Verbose Features
#
# Dictionaries for explanations and improved feature names of the 2016 PUMF dataset.

# %%
import pandas as pd

# %%
fields = ['PPSORT', 'WEIGHT', 'ABOID', 'BFNMEMB', 'CFSTAT', 'Citizen', 'CMA',
       'DETH123', 'HHTYPE',
       'MarStH', 'PR', 'PRIHM', 'REGIND', 'Sex', 'SHELCO',
       'AGEGRP', 'ATTSCH', 'BedRm', 'CFInc', 'CFInc_AT', 'CfSize',
       'CIP2011', 'CIP2011_STEM_SUM', 'CONDO', 'DPGRSUM', 'DTYPE',
       'EFDecile', 'EfDIMBM', 'EFInc', 'EFInc_AT', 'EfSize', 'ETHDER',
       'GENSTAT', 'HCORENEED_IND', 'HDGREE', 'HHInc', 'HHInc_AT',
       'HHMRKINC', 'HHSIZE', 'HLANO', 'IMMCAT5', 'IMMSTAT',
       'LFACT', 'LICO', 'LICO_AT', 'LOC_ST_RES', 'LoLIMA', 'LoLIMB',
       'LoMBM', 'LSTWRK', 'MOB1', 'Mob5', 'MrkInc',
       'MTNNO', 'NOS', 'PKID0_1', 'PKID15_24', 'PKID2_5', 'PKID25',
       'PKID6_14', 'PKIDS', 'POB', 'POBF', 'POBM', 'PR1', 'PR5',
       'PresMortG', 'REPAIR', 'ROOMS', 'SSGRAD', 'Tenur', 'TotInc',
       'TotInc_AT', 'VALUE', 'VisMin', 'WRKACT']

# %%
field_name_data = pd.read_csv('Data_Mining_Names.csv')

field_name_data
# Out:
#    Mapping_Needed     Data_Type  \
# 0             NaN      Discrete
# 1             NaN    Continuous
# 2        Possibly   Categorical
# 3             NaN  Binary (0,1)
# 4        Possibly   Categorical
# ..            ...           ...
# 71            NaN    Continuous
# 72            NaN    Continuous
# 73            NaN    Continuous
# 74         Likely   Categorical
# 75            NaN   Categorical
#
#                                               Meaning  \
# 0                      Unique record (row) identifier
# 1          No. of individuals represented by this row
# 2                        Detailed aboriginal identity
# 3                Membership in a First Nation or band
# 4           Living arrangement (e.g. married, single)
# ..                                                ...
# 71       Total personal income from recurring sources
# 72  Total personal income from recurring sources a...
# 73          Household property value (including land)
# 74                             Visible minority group
# 75     Work activity in 2015 (e.g. worked 1-13 weeks)
#
#                               Definitive_Name dataset_2016
# 0                               Row_ID_PPsort       PPSORT
# 1                                  Row_Weight       WEIGHT
# 2                         Aboriginal_Identity        ABOID
# 3                          FN_Band_Membership      BFNMEMB
# 4               Household_Living_Arrangements       CFSTAT
# ..                                        ...          ...
# 71            Total_Personal_Recurring_Income       TotInc
# 72  Total_Personal_Recurring_Income_After_Tax    TotInc_AT
# 73                             Property_Value        VALUE
# 74                     Visible_Minority_Group       VisMin
# 75               Work_Activity_Status_in_2015       WRKACT
#
# [76 rows x 5 columns]

# %%
data_types = field_name_data['Data_Type']
meanings = field_name_data['Meaning']

descriptions = []

for types, meaning in zip(data_types, meanings):
    descriptions.append(types + ': ' + meaning)

description_dict = dict(zip(field_name_data['dataset_2016'], descriptions))

description_dict
# Out:
# {'PPSORT': 'Discrete: Unique record (row) identifier',
#  'WEIGHT': 'Continuous: No. of individuals represented by this row',
#  'ABOID': 'Categorical: Detailed aboriginal identity',
#  'BFNMEMB': 'Binary (0,1): Membership in a First Nation or band',
#  'CFSTAT': 'Categorical: Living arrangement (e.g. married, single)',
#  'Citizen': 'Categorical: Canadian citizenship status',
#  'CMA': 'Categorical: Area of current residence',
#  'DETH123': 'Binary (1,2): Single or multiple ethnic origin',
#  'HHTYPE': 'Categorical: Household type (e.g. multiple family)',
#  'MarStH': 'Categorical: Marital status',
#  'PR': 'Categorical: Province or territory of current residence',
#  'PRIHM': 'Binary (0,1): Person is primary household maintainer',
#  'REGIND': 'Binary (0,1): Registered or treaty First Nation status',
#  'Sex': 'Binary (1,2): Male or female sex',
#  'SHELCO': 'Continuous: Average monthly cost of shelter',
#  'AGEGRP': 'Categorical: Age bracket',
#  'ATTSCH': 'Categorical: Highest education level ever attended',
#  'BedRm': 'Discrete (0-5+): Number of bedrooms in household',
#  'CFInc': 'Categorical: Census family income bracket',
#  'CFInc_AT': 'Categorical: Census family income bracket after tax',
#  'CfSize': 'Discrete (1-7+): Number of persons in census family',
#  'CIP2011': 'Categorical: Postsecondary field of study',
#  'CIP2011_STEM_SUM': 'Categorical: Postsecondary field (STEM & BHASE)',
#  'CONDO': 'Binary (0,1): Resides in a condominium development',
#  'DPGRSUM': 'Categorical: Population (cultural) group',
#  'DTYPE': 'Categorical: Dwelling structure type (e.g. apartment)',
#  'EFDecile': 'Discrete (1-10): Total family income decile after tax',
#  'EfDIMBM': 'Categorical: Economic family disposable income',
#  'EFInc': 'Categorical: Economic family income bracket',
#  'EFInc_AT': 'Categorical: Economic family income bracket after tax',
#  'EfSize': 'Discrete (1-7+): Number of persons in economic family',
#  'ETHDER': 'Categorical: Ethnic origin',
#  'GENSTAT': 'Categorical: Generation status (e.g. 1st gen. immigrant)',
#  'HCORENEED_IND': 'Binary (0,100): Whether household is inadequate',
#  'HDGREE': 'Categorical: Highest certificate, diploma, or degree',
#  'HHInc': 'Categorical: Household income bracket',
#  'HHInc_AT': 'Categorical: Household income bracket after tax',
#  'HHMRKINC': 'Categorical: Household market income bracket',
#  'HHSIZE': 'Discrete (1-7+): Number of persons in household',
#  'HLANO': 'Categorical: Language most spoken at home',
#  'IMMCAT5': 'Categorical: Immigration category (detailed categories)',
#  'IMMSTAT': 'Categorical: Immigration status (e.g. immigrant vs non)',
#  'LFACT': 'Categorical: Labour force status (e.g. unemployed)',
#  'LICO': 'Binary (1,2): Non-low or low income cut-off economic family',
#  'LICO_AT': 'Binary (1,2): Non-low or low income cut-off economic family after tax',
#  'LOC_ST_RES': 'Categorical: Highest education location vs residence',
#  'LoLIMA': 'Binary (1,2): Non-low or low income measure person after tax',
#  'LoLIMB': 'Binary (1,2): Non-low or low income measure person before tax',
#  'LoMBM': 'Binary (1,2): Non-low or low income Market Based Measure',
#  'LSTWRK': 'Categorical: When last worked for pay or in self-employment',
#  'MOB1': 'Categorical: 1 year mobility status (e.g. interprovincial migrant)',
#  'Mob5': 'Categorical: 5 year mobility status (e.g. interprovincial migrant)',
#  'MrkInc': 'Discrete: Sum personal income from all source',
#  'MTNNO': 'Categorical: Mother tongue (first language spoken)',
#  'NOS': 'Binary (0,1): Housing accomodations are suitable',
#  'PKID0_1': 'Binary (0,1): Presence of children in household aged 0-1',
#  'PKID15_24': 'Binary (0,1): Presence of children in household aged 15-24',
#  'PKID2_5': 'Binary (0,1): Presence of children in household aged 2-5',
#  'PKID25': 'Binary (0,1): Presence of children in household aged 25+',
#  'PKID6_14': 'Binary (0,1): Presence of children in household aged 6_14',
#  'PKIDS': 'Binary (0,1): Presence of children in any household',
#  'POB': 'Categorical: Place of birth',
#  'POBF': "Categorical: Father's place of birth",
#  'POBM': "Categorical: Mother's place of birth",
#  'PR1': 'Categorical: Province or territory of residence 1 year ago',
#  'PR5': 'Categorical: Province or territory of residence 5 years ago',
#  'PresMortG': 'Binary (0,1): Presence of mortgage',
#  'REPAIR': 'Categorical: Need of dwelling repairs',
#  'ROOMS': 'Discrete (0-11+): Number of rooms in household',
#  'SSGRAD': 'Categorical: Secondary school diploma or certificate',
#  'Tenur': 'Binary (1,2): Household owns residence or rents/lives in band housing',
#  'TotInc': 'Continuous: Total personal income from recurring sources',
#  'TotInc_AT': 'Continuous: Total personal income from recurring sources after tax',
#  'VALUE': 'Continuous: Household property value (including land)',
#  'VisMin': 'Categorical: Visible minority group',
#  'WRKACT': 'Categorical: Work activity in 2015 (e.g. worked 1-13 weeks)'}

# %%
name_dict = dict(zip(field_name_data['dataset_2016'], field_name_data['Definitive_Name']))

name_dict
# Out:
# {'PPSORT': 'Row_ID_PPsort',
#  'WEIGHT': 'Row_Weight',
#  'ABOID': 'Aboriginal_Identity',
#  'BFNMEMB': 'FN_Band_Membership',
#  'CFSTAT': 'Household_Living_Arrangements',
#  'Citizen': 'Canadian_Citizenship',
#  'CMA': 'Metro_Area_Current_Residence',
#  'DETH123': 'Single_or_Multiple_Ethnic_Origin',
#  'HHTYPE': 'Household_Family_Status',
#  'MarStH': 'Marital_Status',
#  'PR': 'Province_Current_Residence',
#  'PRIHM': 'Is_Primary_Household_Maintainer',
#  'REGIND': 'Registered_Treaty_Status',
#  'Sex': 'Sex',
#  'SHELCO': 'Shelter_Cost',
#  'AGEGRP': 'Age_Bracket',
#  'ATTSCH': 'Education_Level_Attended',
#  'BedRm': 'Household_Bedroom_Count',
#  'CFInc': 'Census_Family_Income_Bracket',
#  'CFInc_AT': 'Census_Family_Income_After_Tax',
#  'CfSize': 'Census_Family_Size',
#  'CIP2011': 'Postsecondary_Field_of_Study',
#  'CIP2011_STEM_SUM': 'Postsecondary_Field_STEM_or_BHASE',
#  'CONDO': 'Condominium_Membership',
#  'DPGRSUM': 'Population_Group',
#  'DTYPE': 'Dwelling_Structure_Type',
#  'EFDecile': 'Economic_Family_Income_Decile_After_Tax',
#  'EfDIMBM': 'Economic_Family_Disposable_Income',
#  'EFInc': 'Economic_Family_Income_Bracket',
#  'EFInc_AT': 'Economic_Family_Income_Bracket_After_Tax',
#  'EfSize': 'Economic_Family_Size',
#  'ETHDER': 'Ethnic_Origin',
#  'GENSTAT': 'Immigrant_Generation_Status',
#  'HCORENEED_IND': 'Household_In_Core_Need',
#  'HDGREE': 'Highest_Certificate_Degree',
#  'HHInc': 'Household_Income_Bracket',
#  'HHInc_AT': 'Household_Income_Bracket_After_Tax',
#  'HHMRKINC': 'Household_Market_Income_Bracket',
#  'HHSIZE': 'Household_Size',
#  'HLANO': 'Home_Language',
#  'IMMCAT5': 'Immigration_Detailed_Category',
#  'IMMSTAT': 'Immigrant_Status',
#  'LFACT': 'Labour_Force_Status',
#  'LICO': 'Ec_Family_Low_Income_Cutoff',
#  'LICO_AT': 'Ec_Family_Low_Income_Cutoff_After_Tax',
#  'LOC_ST_RES': 'Highest_Education_Location_vs_Residence',
#  'LoLIMA': 'Person_Low_Income_Measure_After_Tax',
#  'LoLIMB': 'Person_Low_Income_Measure_Before_Tax',
#  'LoMBM': 'Person_Low_Income_Market_Based_Measure',
#  'LSTWRK': 'When_Last_Worked_For_Income',
#  'MOB1': 'Residence_Mobility_Status_1_Year_Ago',
#  'Mob5': 'Residence_Mobility_Status_5_Year_Ago',
#  'MrkInc': 'Sum_Personal_Income_All',
#  'MTNNO': 'Mother_Tongue',
#  'NOS': 'Housing_Suitability',
#  'PKID0_1': 'Has_Children_In_Household_Age_0_1',
#  'PKID15_24': 'Has_Children_In_Household_Age_15_24',
#  'PKID2_5': 'Has_Children_In_Household_Age_2_5',
#  'PKID25': 'Has_Children_In_Household_Age_25_Plus',
#  'PKID6_14': 'Has_Children_In_Household_Age_6_14',
#  'PKIDS': 'Has_Children_In_Household',
#  'POB': 'Place_of_Birth',
#  'POBF': 'Father_Place_of_Birth',
#  'POBM': 'Mother_Place_of_Birth',
#  'PR1': 'Province_Residence_1_Year_Ago',
#  'PR5': 'Province_Residence_5_Years_Ago',
#  'PresMortG': 'Has_Mortgage',
#  'REPAIR': 'Dwelling_Repair_Need_Status',
#  'ROOMS': 'Household_Room_Count',
#  'SSGRAD': 'Secondary_Degree_Certificate',
#  'Tenur': 'Household_Ownership_or_Not',
#  'TotInc': 'Total_Personal_Recurring_Income',
#  'TotInc_AT': 'Total_Personal_Recurring_Income_After_Tax',
#  'VALUE': 'Property_Value',
#  'VisMin': 'Visible_Minority_Group',
#  'WRKACT': 'Work_Activity_Status_in_2015'}

# %% [markdown]
# ### Pipeline: Verbose Features

# %%
import pandas as pd

def get_verbose_feature_dicts():
    """Return verbose field name dict and verbose field description dict."""
    
    field_name_data = pd.read_csv('Data_Mining_Names.csv')
    
    data_types = field_name_data['Data_Type']
    meanings = field_name_data['Meaning']

    descriptions = []

    for types, meaning in zip(data_types, meanings):
        descriptions.append(types + ': ' + meaning)

    description_dict = dict(zip(field_name_data['dataset_2016'], descriptions))
    name_dict = dict(zip(field_name_data['dataset_2016'], field_name_data['Definitive_Name']))
    
    return description_dict, name_dict


get_verbose_feature_dicts()
# Out:
# ({'PPSORT': 'Discrete: Unique record (row) identifier',
#   'WEIGHT': 'Continuous: No. of individuals represented by this row',
#   'ABOID': 'Categorical: Detailed aboriginal identity',
#   'BFNMEMB': 'Binary (0,1): Membership in a First Nation or band',
#   'CFSTAT': 'Categorical: Living arrangement (e.g. married, single)',
#   'Citizen': 'Categorical: Canadian citizenship status',
#   'CMA': 'Categorical: Area of current residence',
#   'DETH123': 'Binary (1,2): Single or multiple ethnic origin',
#   'HHTYPE': 'Categorical: Household type (e.g. multiple family)',
#   'MarStH': 'Categorical: Marital status',
#   'PR': 'Categorical: Province or territory of current residence',
#   'PRIHM': 'Binary (0,1): Person is primary household maintainer',
#   'REGIND': 'Binary (0,1): Registered or treaty First Nation status',
#   'Sex': 'Binary (1,2): Male or female sex',
#   'SHELCO': 'Continuous: Average monthly cost of shelter',
#   'AGEGRP': 'Categorical: Age bracket',
#   'ATTSCH': 'Categorical: Highest education level ever attended',
#   'BedRm': 'Discrete (0-5+): Number of bedrooms in household',
#   'CFInc': 'Categorical: Census family income bracket',
#   'CFInc_AT': 'Categorical: Census family income bracket after tax',
#   'CfSize': 'Discrete (1-7+): Number of persons in census family',
#   'CIP2011': 'Categorical: Postsecondary field of study',
#   'CIP2011_STEM_SUM': 'Categorical: Postsecondary field (STEM & BHASE)',
#   'CONDO': 'Binary (0,1): Resides in a condominium development',
#   'DPGRSUM': 'Categorical: Population (cultural) group',
#   'DTYPE': 'Categorical: Dwelling structure type (e.g. apartment)',
#   'EFDecile': 'Discrete (1-10): Total family income decile after tax',
#   'EfDIMBM': 'Categorical: Economic family disposable income',
#   'EFInc': 'Categorical: Economic family income bracket',
#   'EFInc_AT': 'Categorical: Economic family income bracket after tax',
#   'EfSize': 'Discrete (1-7+): Number of persons in economic family',
#   'ETHDER': 'Categorical: Ethnic origin',
#   'GENSTAT': 'Categorical: Generation status (e.g. 1st gen. immigrant)',
#   'HCORENEED_IND': 'Binary (0,100): Whether household is inadequate',
#   'HDGREE': 'Categorical: Highest certificate, diploma, or degree',
#   'HHInc': 'Categorical: Household income bracket',
#   'HHInc_AT': 'Categorical: Household income bracket after tax',
#   'HHMRKINC': 'Categorical: Household market income bracket',
#   'HHSIZE': 'Discrete (1-7+): Number of persons in household',
#   'HLANO': 'Categorical: Language most spoken at home',
#   'IMMCAT5': 'Categorical: Immigration category (detailed categories)',
#   'IMMSTAT': 'Categorical: Immigration status (e.g. immigrant vs non)',
#   'LFACT': 'Categorical: Labour force status (e.g. unemployed)',
#   'LICO': 'Binary (1,2): Non-low or low income cut-off economic family',
#   'LICO_AT': 'Binary (1,2): Non-low or low income cut-off economic family after tax',
#   'LOC_ST_RES': 'Categorical: Highest education location vs residence',
#   'LoLIMA': 'Binary (1,2): Non-low or low income measure person after tax',
#   'LoLIMB': 'Binary (1,2): Non-low or low income measure person before tax',
#   'LoMBM': 'Binary (1,2): Non-low or low income Market Based Measure',
#   'LSTWRK': 'Categorical: When last worked for pay or in self-employment',
#   'MOB1': 'Categorical: 1 year mobility status (e.g. interprovincial migrant)',
#   'Mob5': 'Categorical: 5 year mobility status (e.g. interprovincial migrant)',
#   'MrkInc': 'Discrete: Sum personal income from all source',
#   'MTNNO': 'Categorical: Mother tongue (first language spoken)',
#   'NOS': 'Binary (0,1): Housing accomodations are suitable',
#   'PKID0_1': 'Binary (0,1): Presence of children in household aged 0-1',
#   'PKID15_24': 'Binary (0,1): Presence of children in household aged 15-24',
#   'PKID2_5': 'Binary (0,1): Presence of children in household aged 2-5',
#   'PKID25': 'Binary (0,1): Presence of children in household aged 25+',
#   'PKID6_14': 'Binary (0,1): Presence of children in household aged 6_14',
#   'PKIDS': 'Binary (0,1): Presence of children in any household',
#   'POB': 'Categorical: Place of birth',
#   'POBF': "Categorical: Father's place of birth",
#   'POBM': "Categorical: Mother's place of birth",
#   'PR1': 'Categorical: Province or territory of residence 1 year ago',
#   'PR5': 'Categorical: Province or territory of residence 5 years ago',
#   'PresMortG': 'Binary (0,1): Presence of mortgage',
#   'REPAIR': 'Categorical: Need of dwelling repairs',
#   'ROOMS': 'Discrete (0-11+): Number of rooms in household',
#   'SSGRAD': 'Categorical: Secondary school diploma or certificate',
#   'Tenur': 'Binary (1,2): Household owns residence or rents/lives in band housing',
#   'TotInc': 'Continuous: Total personal income from recurring sources',
#   'TotInc_AT': 'Continuous: Total personal income from recurring sources after tax',
#   'VALUE': 'Continuous: Household property value (including land)',
#   'VisMin': 'Categorical: Visible minority group',
#   'WRKACT': 'Categorical: Work activity in 2015 (e.g. worked 1-13 weeks)'},
#  {'PPSORT': 'Row_ID_PPsort',
#   'WEIGHT': 'Row_Weight',
#   'ABOID': 'Aboriginal_Identity',
#   'BFNMEMB': 'FN_Band_Membership',
#   'CFSTAT': 'Household_Living_Arrangements',
#   'Citizen': 'Canadian_Citizenship',
#   'CMA': 'Metro_Area_Current_Residence',
#   'DETH123': 'Single_or_Multiple_Ethnic_Origin',
#   'HHTYPE': 'Household_Family_Status',
#   'MarStH': 'Marital_Status',
#   'PR': 'Province_Current_Residence',
#   'PRIHM': 'Is_Primary_Household_Maintainer',
#   'REGIND': 'Registered_Treaty_Status',
#   'Sex': 'Sex',
#   'SHELCO': 'Shelter_Cost',
#   'AGEGRP': 'Age_Bracket',
#   'ATTSCH': 'Education_Level_Attended',
#   'BedRm': 'Household_Bedroom_Count',
#   'CFInc': 'Census_Family_Income_Bracket',
#   'CFInc_AT': 'Census_Family_Income_After_Tax',
#   'CfSize': 'Census_Family_Size',
#   'CIP2011': 'Postsecondary_Field_of_Study',
#   'CIP2011_STEM_SUM': 'Postsecondary_Field_STEM_or_BHASE',
#   'CONDO': 'Condominium_Membership',
#   'DPGRSUM': 'Population_Group',
#   'DTYPE': 'Dwelling_Structure_Type',
#   'EFDecile': 'Economic_Family_Income_Decile_After_Tax',
#   'EfDIMBM': 'Economic_Family_Disposable_Income',
#   'EFInc': 'Economic_Family_Income_Bracket',
#   'EFInc_AT': 'Economic_Family_Income_Bracket_After_Tax',
#   'EfSize': 'Economic_Family_Size',
#   'ETHDER': 'Ethnic_Origin',
#   'GENSTAT': 'Immigrant_Generation_Status',
#   'HCORENEED_IND': 'Household_In_Core_Need',
#   'HDGREE': 'Highest_Certificate_Degree',
#   'HHInc': 'Household_Income_Bracket',
#   'HHInc_AT': 'Household_Income_Bracket_After_Tax',
#   'HHMRKINC': 'Household_Market_Income_Bracket',
#   'HHSIZE': 'Household_Size',
#   'HLANO': 'Home_Language',
#   'IMMCAT5': 'Immigration_Detailed_Category',
#   'IMMSTAT': 'Immigrant_Status',
#   'LFACT': 'Labour_Force_Status',
#   'LICO': 'Ec_Family_Low_Income_Cutoff',
#   'LICO_AT': 'Ec_Family_Low_Income_Cutoff_After_Tax',
#   'LOC_ST_RES': 'Highest_Education_Location_vs_Residence',
#   'LoLIMA': 'Person_Low_Income_Measure_After_Tax',
#   'LoLIMB': 'Person_Low_Income_Measure_Before_Tax',
#   'LoMBM': 'Person_Low_Income_Market_Based_Measure',
#   'LSTWRK': 'When_Last_Worked_For_Income',
#   'MOB1': 'Residence_Mobility_Status_1_Year_Ago',
#   'Mob5': 'Residence_Mobility_Status_5_Year_Ago',
#   'MrkInc': 'Sum_Personal_Income_All',
#   'MTNNO': 'Mother_Tongue',
#   'NOS': 'Housing_Suitability',
#   'PKID0_1': 'Has_Children_In_Household_Age_0_1',
#   'PKID15_24': 'Has_Children_In_Household_Age_15_24',
#   'PKID2_5': 'Has_Children_In_Household_Age_2_5',
#   'PKID25': 'Has_Children_In_Household_Age_25_Plus',
#   'PKID6_14': 'Has_Children_In_Household_Age_6_14',
#   'PKIDS': 'Has_Children_In_Household',
#   'POB': 'Place_of_Birth',
#   'POBF': 'Father_Place_of_Birth',
#   'POBM': 'Mother_Place_of_Birth',
#   'PR1': 'Province_Residence_1_Year_Ago',
#   'PR5': 'Province_Residence_5_Years_Ago',
#   'PresMortG': 'Has_Mortgage',
#   'REPAIR': 'Dwelling_Repair_Need_Status',
#   'ROOMS': 'Household_Room_Count',
#   'SSGRAD': 'Secondary_Degree_Certificate',
#   'Tenur': 'Household_Ownership_or_Not',
#   'TotInc': 'Total_Personal_Recurring_Income',
#   'TotInc_AT': 'Total_Personal_Recurring_Income_After_Tax',
#   'VALUE': 'Property_Value',
#   'VisMin': 'Visible_Minority_Group',
#   'WRKACT': 'Work_Activity_Status_in_2015'})

# %% [markdown]
# ---
#
# ## Discretization
#
# Converting continuous and wide-domain discrete values into categorical deciles.

# %%
import pandas as pd

field_name_data = pd.read_csv('Data_Mining_Names.csv')

data_types = field_name_data['Data_Type']
dataset_names = field_name_data['dataset_2016']

to_categorize = ['AGEP', 'WKSWKP']

for types, names in zip(data_types, dataset_names):
    if types in ('Discrete', 'Continuous') and names not in ('PPSORT', 'WEIGHT'):
        # Omitting row identifier and row weight (should not be used)
        to_categorize.append(names)

dataset_names = field_name_data['dataset_1991']
        
for types, names in zip(data_types, dataset_names):
    if types in ('Discrete', 'Continuous') and names not in ('WEIGHTP'):
        # Omitting row weight (should not be used)
        if names != '-':
            to_categorize.append(names)

to_categorize
# Out:
# ['AGEP',
#  'WKSWKP',
#  'SHELCO',
#  'MrkInc',
#  'TotInc_AT',
#  'TotInc',
#  'VALUE',
#  'TOTINCP',
#  'VALUEP']

# %%
dataset_2016 = pd.read_csv('pumf-98M0001-E-2016-individuals_F1.csv')

dataset_2016['SHELCO']
# Out:
# 0         2500
# 1         2400
# 2         2500
# 3         1300
# 4          700
#           ...
# 930416     600
# 930417    1900
# 930418    3294
# 930419    1500
# 930420    1400
# Name: SHELCO, Length: 930421, dtype: int64

# %%
pd.qcut(dataset_2016['SHELCO'], 10, False)
# Out:
# 0         8
# 1         8
# 2         8
# 3         4
# 4         1
# 5         4
# 6         3
# 7         2
# 8         2
# 9         8
# 10        7
# 11        6
# 12        1
# 13        9
# 14        8
# 15        7
# 16        7
# 17        0
# 18        2
# 19        8
# 20        8
# 21        9
# 22        4
# 23        8
# 24        2
# 25        4
# 26        9
# 27        9
# 28        9
# 29        8
#          ..
# 930391    5
# 930392    6
# 930393    5
# 930394    5
# 930395    5
# 930396    2
# 930397    0
# 930398    1
# 930399    5
# 930400    4
# 930401    4
# 930402    4
# 930403    2
# 930404    1
# 930405    7
# 930406    7
# 930407    5
# 930408    4
# 930409    4
# 930410    4
# 930411    5
# 930412    4
# 930413    5
# 930414    5
# 930415    5
# 930416    1
# 930417    7
# 930418    9
# 930419    5
# 930420    5
# Name: SHELCO, Length: 930421, dtype: int64

# %% [markdown]
# ### Pipeline: Discretization

# %%
import pandas as pd

def discretify(dataset, quantiles=10, target_fields=None,
               invalid_quantile = 88):
    """Convert target fields in dataset to quantile categories."""
    
    target_fields = target_fields if target_fields else ['AGEP', 'WKSWKP', 'SHELCO', 'MrkInc', 'TotInc_AT',
                                                         'TotInc', 'VALUE', 'TOTINCP', 'VALUEP']
    invalid_values = {
        'AGEP': [98],
        'WKSWKP': [99],
        'SHELCO': [],
        'MrkInc': [88888888, 99999999],
        'TotInc': [88888888, 99999999],
        'TotInc_AT': [88888888, 99999999],
        'VALUE': [88888888, 99999999],
        'VALUEP': [999999],
        'TOTINCP': [9999999]
    }
    
    dataset_copy = dataset.copy()

    for continuous in target_fields:
        if continuous in dataset_copy:
            print(continuous)
            values = []
            quantile_values = pd.qcut(dataset_copy[continuous].rank(method='first'), quantiles, False)

            for value, quantile in zip(dataset_copy[continuous], quantile_values):
                if value in invalid_values[continuous]:
                    values.append(invalid_quantile)
                else:
                    values.append(quantile)

            dataset_copy[continuous] = values
    
    return dataset_copy


discretify(dataset_2016)
# Out:
# SHELCO
# MrkInc
# TotInc_AT
# TotInc
# VALUE
#         PPSORT     WEIGHT  WT1  WT2         WT3         WT4  WT5         WT6  \
# 0       453141  37.037277  0.0  0.0    0.000000    0.000000  0.0    0.000000
# 1       923226  37.037277  0.0  0.0    0.000000    0.000000  0.0    0.000000
# 2       385097  37.037277  0.0  0.0    0.000000    0.000000  0.0    0.000000
# 3       732612  37.037277  0.0  0.0    0.000000    0.000000  0.0    0.000000
# 4       143665  37.120914  0.0  0.0    0.000000    0.000000  0.0    0.000000
# ...        ...        ...  ...  ...         ...         ...  ...         ...
# 930416  700854  37.037277  0.0  0.0    0.000000    0.000000  0.0  592.596438
# 930417  821443  37.037277  0.0  0.0    0.000000    0.000000  0.0    0.000000
# 930418  116531  37.042280  0.0  0.0  592.676474    0.000000  0.0    0.000000
# 930419  499993  37.037277  0.0  0.0    0.000000  592.596438  0.0    0.000000
# 930420  339051  37.037277  0.0  0.0    0.000000  592.596438  0.0    0.000000
#
#         WT7         WT8  ...  Subsidy  Tenur  TotInc  TotInc_AT  VALUE  \
# 0       0.0    0.000000  ...        9      1       7          7      4
# 1       0.0    0.000000  ...        9      1      88         88      4
# 2       0.0    0.000000  ...        9      1      88         88      4
# 3       0.0  592.596438  ...        9      1       4          5      6
# 4       0.0    0.000000  ...        9      1       3          3      0
# ...     ...         ...  ...      ...    ...     ...        ...    ...
# 930416  0.0    0.000000  ...        9      1       7          7      6
# 930417  0.0    0.000000  ...        8      8       6          6     88
# 930418  0.0    0.000000  ...        9      1       6          6      5
# 930419  0.0    0.000000  ...        0      2       2          3     88
# 930420  0.0    0.000000  ...        0      2       1          0     88
#
#         VisMin     Wages  WKSWRK  WRKACT  YRIMM
# 0           13     95000       6      11   9999
# 1           13  99999999       9      99   9999
# 2           13  99999999       9      99   9999
# 3           13     19000       6      11   9999
# 4           13     29000       5       9   9999
# ...        ...       ...     ...     ...    ...
# 930416      13    130000       6      11   9999
# 930417      13     78000       6      11   9999
# 930418      13     81000       5       9   9999
# 930419       2  99999999       9       1      2
# 930420       2  99999999       6      12   9999
#
# [930421 rows x 141 columns]

# %% [markdown]
# ---
#
# ## Language Mapping
#
# Mappings languages between the 2016 and 1991 datasets, and providing standardized language group names.

# %%
import pandas as pd

language_mappings = pd.read_csv('Language_Mappings.csv')

language_mappings
# Out:
#     HLANO_2016_ID                     HLANO_(Home_Language)  MTNNO_2016_ID  \
# 0             NaN                                       NaN            NaN
# 1             NaN                                       NaN            NaN
# 2             NaN                                       NaN            NaN
# 3             2.0                      Aboriginal languages            2.0
# 4            24.0                       All other languages           32.0
# 5             NaN                                       NaN            NaN
# 6            11.0                                    Arabic            3.0
# 7            20.0                  Austro-Asiatic languages           20.0
# 8            17.0                                 Cantonese            5.0
# 9            19.0                         Chinese languages            6.0
# 10            6.0                                    German            7.0
# 11            NaN                                       NaN            9.0
# 12            3.0                                   Italian           13.0
# 13            NaN                                       NaN            NaN
# 14            NaN                                       NaN           28.0
# 15           18.0                                  Mandarin            4.0
# 16            NaN                                       NaN           31.0
# 17            1.0                  No non-official language            1.0
# 18           88.0                             Not available           88.0
# 19           12.0  Other Afro-Asiatic and African languages           25.0
# 20            NaN                                       NaN           27.0
# 21           22.0  Other East and Southeast Asian languages           29.0
# 22           10.0                  Other European languages           21.0
# 23            NaN                                       NaN            8.0
# 24           16.0              Other Indo-Iranian languages           12.0
# 25            9.0                          Slavic languages           23.0
# 26           15.0                           Persian (Farsi)           11.0
# 27            8.0                                    Polish           14.0
# 28            5.0                                Portuguese           15.0
# 29           13.0                         Punjabi (Panjabi)           16.0
# 30            7.0                                   Russian           22.0
# 31            4.0                                   Spanish           17.0
# 32           21.0              Tagalog (Pilipino, Filipino)           30.0
# 33           23.0                                     Tamil           26.0
# 34            NaN                                       NaN           18.0
# 35            NaN                                       NaN           24.0
# 36           14.0                                      Urdu           10.0
# 37            NaN                                       NaN           19.0
#
#                                 MTNNO_(Mother_Tongue)  HLNP_1991_ID  \
# 0                                                 NaN           3.0
# 1                                                 NaN           1.0
# 2                                                 NaN           2.0
# 3                                Aboriginal languages           4.0
# 4                          All other single languages          15.0
# 5                                                 NaN          16.0
# 6                                              Arabic          12.0
# 7                            Austro-Asiatic languages          11.0
# 8                                           Cantonese           NaN
# 9                                   Chinese languages          10.0
# 10                                             German           5.0
# 11                                              Greek           NaN
# 12                                            Italian           6.0
# 13                                                NaN           NaN
# 14                                             Korean           NaN
# 15                                           Mandarin           NaN
# 16  Niger-Congo languages and other African languages           NaN
# 17                           No non-official language           NaN
# 18                                      Not available          98.0
# 19                       Other Afro-Asiatic languages           NaN
# 20                          Other Dravidian languages           NaN
# 21           Other East and Southeast Asian languages           NaN
# 22                           Other European languages           NaN
# 23                           Other Germanic languages           NaN
# 24                       Other Indo-Iranian languages          14.0
# 25                             Other Slavic languages           NaN
# 26                                    Persian (Farsi)           NaN
# 27                                             Polish           9.0
# 28                                         Portuguese           8.0
# 29                                  Punjabi (Panjabi)          13.0
# 30                                            Russian           NaN
# 31                                            Spanish           7.0
# 32                       Tagalog (Pilipino, Filipino)           NaN
# 33                                              Tamil           NaN
# 34                                          Ukrainian           NaN
# 35                                   Uralic languages           NaN
# 36                                               Urdu           NaN
# 37                                         Vietnamese           NaN
#
#              HLNP_(Home_Language)  MTNP_1991_ID  \
# 0              English and French           3.0
# 1         English single response           1.0
# 2          French single response           2.0
# 3       NOL: Aboriginal languages           4.0
# 4                      NOL: Other          18.0
# 5    NOL: Other (Atl./Terr. only)          19.0
# 6                     NOL: Arabic          15.0
# 7   NOL: Austro-Asiatic languages          14.0
# 8                             NaN           NaN
# 9                    NOL: Chinese          13.0
# 10                    NOL: German           5.0
# 11                            NaN          12.0
# 12                   NOL: Italian           7.0
# 13                            NaN           6.0
# 14                            NaN           NaN
# 15                            NaN           NaN
# 16                            NaN           NaN
# 17                            NaN           NaN
# 18                  Not available          98.0
# 19                            NaN           NaN
# 20                            NaN           NaN
# 21                            NaN           NaN
# 22                            NaN           NaN
# 23                            NaN           NaN
# 24          NOL: Other Indo-Iran.          17.0
# 25                            NaN           NaN
# 26                            NaN           NaN
# 27                    NOL: Polish          10.0
# 28                NOL: Portuguese           9.0
# 29                   NOL: Punjabi          16.0
# 30                            NaN           NaN
# 31                   NOL: Spanish           8.0
# 32                            NaN           NaN
# 33                            NaN           NaN
# 34                            NaN          11.0
# 35                            NaN           NaN
# 36                            NaN           NaN
# 37                            NaN           NaN
#
#              MTNP_(Mother_Tongue)             Equivalency_Class
# 0              English and French            Official_Languages
# 1         English single response            Official_Languages
# 2          French single response            Official_Languages
# 3       NOL: Aboriginal languages                    Aboriginal
# 4                      NOL: Other           All_Other_Languages
# 5    NOL: Other (Atl./Terr. only)           All_Other_Languages
# 6                     NOL: Arabic                        Arabic
# 7   NOL: Austro-Asiatic languages      Austro-Asiatic Languages
# 8                             NaN             Chinese_Languages
# 9                    NOL: Chinese             Chinese_Languages
# 10                    NOL: German                        German
# 11                     NOL: Greek           All_Other_Languages
# 12                   NOL: Italian                       Italian
# 13    NOL: Netherlandic languages           All_Other_Languages
# 14                            NaN           All_Other_Languages
# 15                            NaN             Chinese_Languages
# 16                            NaN           All_Other_Languages
# 17                            NaN            Official_Languages
# 18                  Not available                 Not_Available
# 19                            NaN           All_Other_Languages
# 20                            NaN           All_Other_Languages
# 21                            NaN           All_Other_Languages
# 22                            NaN           All_Other_Languages
# 23                            NaN           All_Other_Languages
# 24          NOL: Other Indo-Iran.  Other_Indo_Iranian_Languages
# 25                            NaN           All_Other_Languages
# 26                            NaN  Other_Indo_Iranian_Languages
# 27                    NOL: Polish                        Polish
# 28                NOL: Portuguese                    Portuguese
# 29                   NOL: Punjabi                       Punjabi
# 30                            NaN           All_Other_Languages
# 31                   NOL: Spanish                       Spanish
# 32                            NaN           All_Other_Languages
# 33                            NaN           All_Other_Languages
# 34                 NOL: Ukrainian           All_Other_Languages
# 35                            NaN           All_Other_Languages
# 36                            NaN  Other_Indo_Iranian_Languages
# 37                            NaN      Austro-Asiatic Languages

# %%
from math import isnan

print(isnan(language_mappings['HLANO_2016_ID'][0]))
print(isnan(language_mappings['HLANO_2016_ID'][3]))
# Out:
# True
# False

# %% [markdown]
# ### Pipeline: Language Mapping

# %%
import pandas as pd
from math import isnan

def get_language_mappings():
    """Get language mapping dicts, separated into subdicts by feature name."""

    hlano = {}
    mtnno = {}
    hlnp = {}
    mtnp = {}
    classes = set()

    language_mappings = pd.read_csv('Language_Mappings.csv')
    
    for row in list(language_mappings.itertuples()):
        # print(row[1])
        # print(row[3])
        # print(row[5])
        # print(row[7])
        # print(row[9])

        classes.add(row[9])
        
        if not isnan(row[1]):
            hlano[int(row[1])] = row[9]
        if not isnan(row[3]):
            mtnno[int(row[3])] = row[9]
        if not isnan(row[5]):
            hlnp[int(row[5])] = row[9]
        if not isnan(row[7]):
            mtnp[int(row[7])] = row[9]

    return {
        'hlano': hlano,
        'mtnno': mtnno,
        'hlnp': hlnp,
        'mtnp': mtnp,
        'classes': list(classes)
    }


get_language_mappings()
# Out:
# {'hlano': {2: 'Aboriginal',
#   24: 'All_Other_Languages',
#   11: 'Arabic',
#   20: 'Austro-Asiatic Languages',
#   17: 'Chinese_Languages',
#   19: 'Chinese_Languages',
#   6: 'German',
#   3: 'Italian',
#   18: 'Chinese_Languages',
#   1: 'Official_Languages',
#   88: 'Not_Available',
#   12: 'All_Other_Languages',
#   22: 'All_Other_Languages',
#   10: 'All_Other_Languages',
#   16: 'Other_Indo_Iranian_Languages',
#   9: 'All_Other_Languages',
#   15: 'Other_Indo_Iranian_Languages',
#   8: 'Polish',
#   5: 'Portuguese',
#   13: 'Punjabi',
#   7: 'All_Other_Languages',
#   4: 'Spanish',
#   21: 'All_Other_Languages',
#   23: 'All_Other_Languages',
#   14: 'Other_Indo_Iranian_Languages'},
#  'mtnno': {2: 'Aboriginal',
#   32: 'All_Other_Languages',
#   3: 'Arabic',
#   20: 'Austro-Asiatic Languages',
#   5: 'Chinese_Languages',
#   6: 'Chinese_Languages',
#   7: 'German',
#   9: 'All_Other_Languages',
#   13: 'Italian',
#   28: 'All_Other_Languages',
#   4: 'Chinese_Languages',
#   31: 'All_Other_Languages',
#   1: 'Official_Languages',
#   88: 'Not_Available',
#   25: 'All_Other_Languages',
#   27: 'All_Other_Languages',
#   29: 'All_Other_Languages',
#   21: 'All_Other_Languages',
#   8: 'All_Other_Languages',
#   12: 'Other_Indo_Iranian_Languages',
#   23: 'All_Other_Languages',
#   11: 'Other_Indo_Iranian_Languages',
#   14: 'Polish',
#   15: 'Portuguese',
#   16: 'Punjabi',
#   22: 'All_Other_Languages',
#   17: 'Spanish',
#   30: 'All_Other_Languages',
#   26: 'All_Other_Languages',
#   18: 'All_Other_Languages',
#   24: 'All_Other_Languages',
#   10: 'Other_Indo_Iranian_Languages',
#   19: 'Austro-Asiatic Languages'},
#  'hlnp': {3: 'Official_Languages',
#   1: 'Official_Languages',
#   2: 'Official_Languages',
#   4: 'Aboriginal',
#   15: 'All_Other_Languages',
#   16: 'All_Other_Languages',
#   12: 'Arabic',
#   11: 'Austro-Asiatic Languages',
#   10: 'Chinese_Languages',
#   5: 'German',
#   6: 'Italian',
#   98: 'Not_Available',
#   14: 'Other_Indo_Iranian_Languages',
#   9: 'Polish',
#   8: 'Portuguese',
#   13: 'Punjabi',
#   7: 'Spanish'},
#  'mtnp': {3: 'Official_Languages',
#   1: 'Official_Languages',
#   2: 'Official_Languages',
#   4: 'Aboriginal',
#   18: 'All_Other_Languages',
#   19: 'All_Other_Languages',
#   15: 'Arabic',
#   14: 'Austro-Asiatic Languages',
#   13: 'Chinese_Languages',
#   5: 'German',
#   12: 'All_Other_Languages',
#   7: 'Italian',
#   6: 'All_Other_Languages',
#   98: 'Not_Available',
#   17: 'Other_Indo_Iranian_Languages',
#   10: 'Polish',
#   9: 'Portuguese',
#   16: 'Punjabi',
#   8: 'Spanish',
#   11: 'All_Other_Languages'},
#  'classes': ['Polish',
#   'German',
#   'Official_Languages',
#   'Punjabi',
#   'Austro-Asiatic Languages',
#   'Portuguese',
#   'Italian',
#   'Spanish',
#   'Other_Indo_Iranian_Languages',
#   'Chinese_Languages',
#   'All_Other_Languages',
#   'Arabic',
#   'Not_Available',
#   'Aboriginal']}

# %% [markdown]
# ---
#
# ## Unified Features
#
# Conversion of and restriction to unified 1991-2016 fields.

# %%
import pandas as pd

field_name_data = pd.read_csv('Data_Mining_Names.csv')

field_name_data
# Out:
#    Mapping_Needed        Data_Type  \
# 0             NaN      Categorical
# 1             NaN      Categorical
# 2             NaN      Categorical
# 3             NaN      Categorical
# 4             NaN      Categorical
# ..            ...              ...
# 71            NaN       Continuous
# 72            NaN  Discrete (1-7+)
# 73            NaN       Continuous
# 74            NaN       Continuous
# 75            NaN      Categorical
#
#                                            Meaning  \
# 0           Census family income bracket after tax
# 1         Dwelling structure type (e.g. apartment)
# 2                Economic family disposable income
# 3                   Economic family income bracket
# 4         Economic family income bracket after tax
# ..                                             ...
# 71    Total personal income from recurring sources
# 72                  Number of persons in household
# 73       Household property value (including land)
# 74      No. of individuals represented by this row
# 75  Work activity in 2015 (e.g. worked 1-13 weeks)
#
#                              Definitive_Name dataset_2016 dataset_1991  \
# 0             Census_Family_Income_After_Tax     CFInc_AT            -
# 1                    Dwelling_Structure_Type        DTYPE            -
# 2          Economic_Family_Disposable_Income      EfDIMBM            -
# 3             Economic_Family_Income_Bracket        EFInc            -
# 4   Economic_Family_Income_Bracket_After_Tax     EFInc_AT            -
# ..                                       ...          ...          ...
# 71           Total_Personal_Recurring_Income       TotInc      TOTINCP
# 72                            Household_Size       HHSIZE       UNITSP
# 73                            Property_Value        VALUE       VALUEP
# 74                                Row_Weight       WEIGHT      WEIGHTP
# 75              Work_Activity_Status_in_2015       WRKACT       WKSWKP
#
#                                     Notes
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 71                                    NaN
# 72                                    NaN
# 73                                    NaN
# 74                                    NaN
# 75  1991 may need to be discretized; (99)
#
# [76 rows x 7 columns]

# %% [markdown]
# ### Pipelines: Unified Features

# %%
import pandas as pd

def get_unified_feature_dicts():
    """Return 1991-2016 unified verbose field name dict and 1991-2016 unified verbose field description dict."""
    
    field_name_data = pd.read_csv('Data_Mining_Names.csv')
    
    data_types = field_name_data['Data_Type']
    meanings = field_name_data['Meaning']

    descriptions = []

    for types, meaning in zip(data_types, meanings):
        descriptions.append(types + ': ' + meaning)

    description_dict = dict(zip(field_name_data['dataset_2016'], descriptions))
    name_dict = dict(zip(field_name_data['dataset_2016'], field_name_data['Definitive_Name']))
    
    description_dict.update(dict(zip(field_name_data['dataset_1991'], descriptions)))
    name_dict.update(dict(zip(field_name_data['dataset_1991'], field_name_data['Definitive_Name'])))
    
    del description_dict['-']
    del name_dict['-']
    
    return description_dict, name_dict


get_unified_feature_dicts()
# Out:
# ({'CFInc_AT': 'Categorical: Census family income bracket after tax',
#   'DTYPE': 'Categorical: Dwelling structure type (e.g. apartment)',
#   'EfDIMBM': 'Categorical: Economic family disposable income',
#   'EFInc': 'Categorical: Economic family income bracket',
#   'EFInc_AT': 'Categorical: Economic family income bracket after tax',
#   'EFDecile': 'Discrete (1-10): Total family income decile after tax',
#   'LICO_AT': 'Binary (1,2): Non-low or low income cut-off economic family after tax',
#   'PKIDS': 'Binary (0,1): Presence of children in any household',
#   'PKID0_1': 'Binary (0,1): Presence of children in household aged 0-1',
#   'PKID15_24': 'Binary (0,1): Presence of children in household aged 15-24',
#   'PKID2_5': 'Binary (0,1): Presence of children in household aged 2-5',
#   'PKID25': 'Binary (0,1): Presence of children in household aged 25+',
#   'PKID6_14': 'Binary (0,1): Presence of children in household aged 6_14',
#   'PresMortG': 'Binary (0,1): Presence of mortgage',
#   'LOC_ST_RES': 'Categorical: Highest education location vs residence',
#   'BedRm': 'Discrete (0-5+): Number of bedrooms in household',
#   'HCORENEED_IND': 'Binary (0,100): Whether household is inadequate',
#   'HHInc_AT': 'Categorical: Household income bracket after tax',
#   'HHMRKINC': 'Categorical: Household market income bracket',
#   'NOS': 'Binary (0,1): Housing accomodations are suitable',
#   'GENSTAT': 'Categorical: Generation status (e.g. 1st gen. immigrant)',
#   'IMMCAT5': 'Categorical: Immigration category (detailed categories)',
#   'LoMBM': 'Binary (1,2): Non-low or low income Market Based Measure',
#   'LoLIMA': 'Binary (1,2): Non-low or low income measure person after tax',
#   'LoLIMB': 'Binary (1,2): Non-low or low income measure person before tax',
#   'POBF': "Categorical: Father's place of birth",
#   'POBM': "Categorical: Mother's place of birth",
#   'DPGRSUM': 'Categorical: Population (cultural) group',
#   'CIP2011_STEM_SUM': 'Categorical: Postsecondary field (STEM & BHASE)',
#   'PPSORT': 'Discrete: Unique record (row) identifier',
#   'SHELCO': 'Continuous: Average monthly cost of shelter',
#   'DETH123': 'Binary (1,2): Single or multiple ethnic origin',
#   'MrkInc': 'Discrete: Sum personal income from all source',
#   'TotInc_AT': 'Continuous: Total personal income from recurring sources after tax',
#   'VisMin': 'Categorical: Visible minority group',
#   'ABOID': 'Categorical: Detailed aboriginal identity',
#   'AGEGRP': 'Categorical: Age bracket',
#   'BFNMEMB': 'Binary (0,1): Membership in a First Nation or band',
#   'CFInc': 'Categorical: Census family income bracket',
#   'CfSize': 'Discrete (1-7+): Number of persons in census family',
#   'CFSTAT': 'Categorical: Census family living arrangement (e.g. married, single)',
#   'Citizen': 'Categorical: Canadian citizenship status',
#   'CMA': 'Categorical: Area of current residence',
#   'REPAIR': 'Categorical: Need of dwelling repairs',
#   'CIP2011': 'Categorical: Postsecondary field of study',
#   'HDGREE': 'Categorical: Highest certificate, diploma, or degree',
#   'EfSize': 'Discrete (1-7+): Number of persons in economic family',
#   'ETHDER': 'Categorical: Ethnic origin',
#   'HHInc': 'Categorical: Household income bracket',
#   'HLANO': 'Categorical: Language most spoken at home',
#   'ATTSCH': 'Categorical: Highest education level ever attended',
#   'HHTYPE': 'Categorical: Household type (e.g. multiple family)',
#   'IMMSTAT': 'Categorical: Immigration status (e.g. immigrant vs non)',
#   'LICO': 'Binary (1,2): Non-low or low income cut-off economic family',
#   'LFACT': 'Categorical: Labour force status (e.g. unemployed)',
#   'LSTWRK': 'Categorical: When last worked for pay or in self-employment',
#   'MarStH': 'Categorical: Marital status',
#   'MOB1': 'Categorical: 1 year mobility status (e.g. interprovincial migrant)',
#   'Mob5': 'Categorical: 5 year mobility status (e.g. interprovincial migrant)',
#   'MTNNO': 'Categorical: Mother tongue (first language spoken)',
#   'POB': 'Categorical: Place of birth',
#   'PRIHM': 'Binary (0,1): Person is primary household maintainer',
#   'PR1': 'Categorical: Province or territory of residence 1 year ago',
#   'PR5': 'Categorical: Province or territory of residence 5 years ago',
#   'PR': 'Categorical: Province or territory of current residence',
#   'CONDO': 'Binary (0,1): Resides in a condominium development',
#   'REGIND': 'Binary (0,1): Registered or treaty Indian status',
#   'ROOMS': 'Discrete (0-11+): Number of rooms in household',
#   'SSGRAD': 'Categorical: Secondary school diploma or certificate',
#   'Sex': 'Binary (1,2): Male or female sex',
#   'Tenur': 'Binary (1,2): Household owns residence or rents/lives in band housing',
#   'TotInc': 'Continuous: Total personal income from recurring sources',
#   'HHSIZE': 'Discrete (1-7+): Number of persons in household',
#   'VALUE': 'Continuous: Household property value (including land)',
#   'WEIGHT': 'Continuous: No. of individuals represented by this row',
#   'WRKACT': 'Categorical: Work activity in 2015 (e.g. worked 1-13 weeks)',
#   'ABETHNCP': 'Categorical: Detailed aboriginal identity',
#   'AGEP': 'Categorical: Age bracket',
#   'BNFNMEMP': 'Binary (0,1): Membership in a First Nation or band',
#   'CFINCP': 'Categorical: Census family income bracket',
#   'CFSIZEP': 'Discrete (1-7+): Number of persons in census family',
#   'CFSTATP': 'Categorical: Census family living arrangement (e.g. married, single)',
#   'CITIZENP': 'Categorical: Canadian citizenship status',
#   'CMAPUMFP': 'Categorical: Area of current residence',
#   'CONDWELP': 'Categorical: Need of dwelling repairs',
#   'DGMFSP': 'Categorical: Postsecondary field of study',
#   'DGREEP': 'Categorical: Highest certificate, diploma, or degree',
#   'EFSIZEP': 'Discrete (1-7+): Number of persons in economic family',
#   'ETHNICRP': 'Categorical: Ethnic origin',
#   'HHINCP': 'Categorical: Household income bracket',
#   'HLNP': 'Categorical: Language most spoken at home',
#   'HLOSP': 'Categorical: Highest education level ever attended',
#   'HTYPEP': 'Categorical: Household type (e.g. multiple family)',
#   'IMMPOPP': 'Categorical: Immigration status (e.g. immigrant vs non)',
#   'INCSTP': 'Binary (1,2): Non-low or low income cut-off economic family',
#   'LFACTP': 'Categorical: Labour force status (e.g. unemployed)',
#   'LSTWKP': 'Categorical: When last worked for pay or in self-employment',
#   'MARSTLP': 'Categorical: Marital status',
#   'MOB1P': 'Categorical: 1 year mobility status (e.g. interprovincial migrant)',
#   'MOB5P': 'Categorical: 5 year mobility status (e.g. interprovincial migrant)',
#   'MTNP': 'Categorical: Mother tongue (first language spoken)',
#   'POBP': 'Categorical: Place of birth',
#   'PRMAINP': 'Binary (0,1): Person is primary household maintainer',
#   'PROV1P': 'Categorical: Province or territory of residence 1 year ago',
#   'PROV5P': 'Categorical: Province or territory of residence 5 years ago',
#   'PROVP': 'Categorical: Province or territory of current residence',
#   'RCONDP': 'Binary (0,1): Resides in a condominium development',
#   'REGINP': 'Binary (0,1): Registered or treaty Indian status',
#   'ROOMP': 'Discrete (0-11+): Number of rooms in household',
#   'SECGRADP': 'Categorical: Secondary school diploma or certificate',
#   'SEXP': 'Binary (1,2): Male or female sex',
#   'TENURP': 'Binary (1,2): Household owns residence or rents/lives in band housing',
#   'TOTINCP': 'Continuous: Total personal income from recurring sources',
#   'UNITSP': 'Discrete (1-7+): Number of persons in household',
#   'VALUEP': 'Continuous: Household property value (including land)',
#   'WEIGHTP': 'Continuous: No. of individuals represented by this row',
#   'WKSWKP': 'Categorical: Work activity in 2015 (e.g. worked 1-13 weeks)'},
#  {'CFInc_AT': 'Census_Family_Income_After_Tax',
#   'DTYPE': 'Dwelling_Structure_Type',
#   'EfDIMBM': 'Economic_Family_Disposable_Income',
#   'EFInc': 'Economic_Family_Income_Bracket',
#   'EFInc_AT': 'Economic_Family_Income_Bracket_After_Tax',
#   'EFDecile': 'Economic_Family_Income_Decile_After_Tax',
#   'LICO_AT': 'Economic_Family_Low_Income_Cutoff_After_Tax',
#   'PKIDS': 'Has_Children_In_Household',
#   'PKID0_1': 'Has_Children_In_Household_Age_0_1',
#   'PKID15_24': 'Has_Children_In_Household_Age_15_24',
#   'PKID2_5': 'Has_Children_In_Household_Age_2_5',
#   'PKID25': 'Has_Children_In_Household_Age_25_Plus',
#   'PKID6_14': 'Has_Children_In_Household_Age_6_14',
#   'PresMortG': 'Has_Mortgage',
#   'LOC_ST_RES': 'Highest_Education_Location_vs_Residence',
#   'BedRm': 'Household_Bedroom_Count',
#   'HCORENEED_IND': 'Household_In_Core_Need',
#   'HHInc_AT': 'Household_Income_Bracket_After_Tax',
#   'HHMRKINC': 'Household_Market_Income_Bracket',
#   'NOS': 'Housing_Suitability',
#   'GENSTAT': 'Immigrant_Generation_Status',
#   'IMMCAT5': 'Immigration_Detailed_Category',
#   'LoMBM': 'Person_Low_Income_Market_Based_Measure',
#   'LoLIMA': 'Person_Low_Income_Measure_After_Tax',
#   'LoLIMB': 'Person_Low_Income_Measure_Before_Tax',
#   'POBF': 'Place_of_Birth_Father',
#   'POBM': 'Place_of_Birth_Mother',
#   'DPGRSUM': 'Population_Group',
#   'CIP2011_STEM_SUM': 'Postsecondary_Field_STEM_or_BHASE',
#   'PPSORT': 'Row_ID_PPsort',
#   'SHELCO': 'Shelter_Cost',
#   'DETH123': 'Single_or_Multiple_Ethnic_Origin',
#   'MrkInc': 'Sum_Personal_Income_All',
#   'TotInc_AT': 'Total_Personal_Recurring_Income_After_Tax',
#   'VisMin': 'Visible_Minority_Group',
#   'ABOID': 'Aboriginal_Identity',
#   'AGEGRP': 'Age_Bracket',
#   'BFNMEMB': 'FN_Band_Membership',
#   'CFInc': 'Census_Family_Income_Bracket',
#   'CfSize': 'Census_Family_Size',
#   'CFSTAT': 'Census_Family_Living_Arrangements',
#   'Citizen': 'Canadian_Citizenship',
#   'CMA': 'Metro_Area_Current_Residence',
#   'REPAIR': 'Dwelling_Repair_Need_Status',
#   'CIP2011': 'Postsecondary_Field_of_Study',
#   'HDGREE': 'Highest_Certificate_Degree',
#   'EfSize': 'Economic_Family_Size',
#   'ETHDER': 'Ethnic_Origin',
#   'HHInc': 'Household_Income_Bracket',
#   'HLANO': 'Home_Language',
#   'ATTSCH': 'Education_Level_Attended',
#   'HHTYPE': 'Household_Family_Status',
#   'IMMSTAT': 'Immigrant_Status',
#   'LICO': 'Economic_Family_Low_Income_Cutoff',
#   'LFACT': 'Labour_Force_Status',
#   'LSTWRK': 'When_Last_Worked_For_Income',
#   'MarStH': 'Marital_Status',
#   'MOB1': 'Residence_Mobility_Status_1_Year_Ago',
#   'Mob5': 'Residence_Mobility_Status_5_Year_Ago',
#   'MTNNO': 'Mother_Tongue',
#   'POB': 'Place_of_Birth',
#   'PRIHM': 'Is_Primary_Household_Maintainer',
#   'PR1': 'Province_Residence_1_Year_Ago',
#   'PR5': 'Province_Residence_5_Years_Ago',
#   'PR': 'Province_Current_Residence',
#   'CONDO': 'Condominium_Membership',
#   'REGIND': 'Registered_Treaty_Status',
#   'ROOMS': 'Household_Room_Count',
#   'SSGRAD': 'Secondary_Degree_Certificate',
#   'Sex': 'Sex',
#   'Tenur': 'Household_Ownership_or_Not',
#   'TotInc': 'Total_Personal_Recurring_Income',
#   'HHSIZE': 'Household_Size',
#   'VALUE': 'Property_Value',
#   'WEIGHT': 'Row_Weight',
#   'WRKACT': 'Work_Activity_Status_in_2015',
#   'ABETHNCP': 'Aboriginal_Identity',
#   'AGEP': 'Age_Bracket',
#   'BNFNMEMP': 'FN_Band_Membership',
#   'CFINCP': 'Census_Family_Income_Bracket',
#   'CFSIZEP': 'Census_Family_Size',
#   'CFSTATP': 'Census_Family_Living_Arrangements',
#   'CITIZENP': 'Canadian_Citizenship',
#   'CMAPUMFP': 'Metro_Area_Current_Residence',
#   'CONDWELP': 'Dwelling_Repair_Need_Status',
#   'DGMFSP': 'Postsecondary_Field_of_Study',
#   'DGREEP': 'Highest_Certificate_Degree',
#   'EFSIZEP': 'Economic_Family_Size',
#   'ETHNICRP': 'Ethnic_Origin',
#   'HHINCP': 'Household_Income_Bracket',
#   'HLNP': 'Home_Language',
#   'HLOSP': 'Education_Level_Attended',
#   'HTYPEP': 'Household_Family_Status',
#   'IMMPOPP': 'Immigrant_Status',
#   'INCSTP': 'Economic_Family_Low_Income_Cutoff',
#   'LFACTP': 'Labour_Force_Status',
#   'LSTWKP': 'When_Last_Worked_For_Income',
#   'MARSTLP': 'Marital_Status',
#   'MOB1P': 'Residence_Mobility_Status_1_Year_Ago',
#   'MOB5P': 'Residence_Mobility_Status_5_Year_Ago',
#   'MTNP': 'Mother_Tongue',
#   'POBP': 'Place_of_Birth',
#   'PRMAINP': 'Is_Primary_Household_Maintainer',
#   'PROV1P': 'Province_Residence_1_Year_Ago',
#   'PROV5P': 'Province_Residence_5_Years_Ago',
#   'PROVP': 'Province_Current_Residence',
#   'RCONDP': 'Condominium_Membership',
#   'REGINP': 'Registered_Treaty_Status',
#   'ROOMP': 'Household_Room_Count',
#   'SECGRADP': 'Secondary_Degree_Certificate',
#   'SEXP': 'Sex',
#   'TENURP': 'Household_Ownership_or_Not',
#   'TOTINCP': 'Total_Personal_Recurring_Income',
#   'UNITSP': 'Household_Size',
#   'VALUEP': 'Property_Value',
#   'WEIGHTP': 'Row_Weight',
#   'WKSWKP': 'Work_Activity_Status_in_2015'})

# %%
import pandas as pd

def get_usable_features():
    """Return 1991 fields and 2016 fields usable for cross-year comparison."""
    
    field_name_data = pd.read_csv('Data_Mining_Names.csv')
    
    features_1991 = []
    features_2016 = []

    for older, newer in zip(field_name_data['dataset_1991'], field_name_data['dataset_2016']):
        if older != '-':
            features_1991.append(older)
            features_2016.append(newer)
    
    return features_1991, features_2016


get_usable_features()
# Out:
# (['ABETHNCP',
#   'AGEP',
#   'BNFNMEMP',
#   'CFINCP',
#   'CFSIZEP',
#   'CFSTATP',
#   'CITIZENP',
#   'CMAPUMFP',
#   'CONDWELP',
#   'DGMFSP',
#   'DGREEP',
#   'EFSIZEP',
#   'ETHNICRP',
#   'HHINCP',
#   'HLNP',
#   'HLOSP',
#   'HTYPEP',
#   'IMMPOPP',
#   'INCSTP',
#   'LFACTP',
#   'LSTWKP',
#   'MARSTLP',
#   'MOB1P',
#   'MOB5P',
#   'MTNP',
#   'POBP',
#   'PRMAINP',
#   'PROV1P',
#   'PROV5P',
#   'PROVP',
#   'RCONDP',
#   'REGINP',
#   'ROOMP',
#   'SECGRADP',
#   'SEXP',
#   'TENURP',
#   'TOTINCP',
#   'UNITSP',
#   'VALUEP',
#   'WEIGHTP',
#   'WKSWKP'],
#  ['ABOID',
#   'AGEGRP',
#   'BFNMEMB',
#   'CFInc',
#   'CfSize',
#   'CFSTAT',
#   'Citizen',
#   'CMA',
#   'REPAIR',
#   'CIP2011',
#   'HDGREE',
#   'EfSize',
#   'ETHDER',
#   'HHInc',
#   'HLANO',
#   'ATTSCH',
#   'HHTYPE',
#   'IMMSTAT',
#   'LICO',
#   'LFACT',
#   'LSTWRK',
#   'MarStH',
#   'MOB1',
#   'Mob5',
#   'MTNNO',
#   'POB',
#   'PRIHM',
#   'PR1',
#   'PR5',
#   'PR',
#   'CONDO',
#   'REGIND',
#   'ROOMS',
#   'SSGRAD',
#   'Sex',
#   'Tenur',
#   'TotInc',
#   'HHSIZE',
#   'VALUE',
#   'WEIGHT',
#   'WRKACT'])
