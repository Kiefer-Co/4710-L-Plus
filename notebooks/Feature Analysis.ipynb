# %% [markdown]
# # Feature Analysis

# %%
import pandas as pd

# %%
shift_1991 = pd.read_csv('1991_LanguageShift.csv')
shift_2016 = pd.read_csv('2016_LanguageShift.csv')
shift_2016_all = pd.read_csv('2016_LanguageShift_All.csv')

# %%
shift_1991
# Out:
#         WEIGHTP  LanguageShift  ABETHNCP  AGEP  BNFNMEMP  CFINCP  CFSIZEP  \
# 0         33.33          False         5     5         2      17        4
# 1         33.33          False         5     0         2      17        4
# 2         33.33          False         5     6         2      21        5
# 3         33.33          False         5     1         2      21        5
# 4         33.33          False         5     8         2       8        2
# ...         ...            ...       ...   ...       ...     ...      ...
# 809649    33.33          False         2     0         2      99        1
# 809650    33.33          False         2     3         2      12        4
# 809651    33.33          False         2     0         2      12        4
# 809652    33.33          False         2     0         2      12        4
# 809653    33.33           True         2     4         2      99        1
#
#         CFSTATP  CITIZENP  CMAPUMFP  ...  RCONDP  REGINP  ROOMP  SECGRADP  \
# 0             4         1       999  ...       2       2     10         2
# 1             7         1       999  ...       2       2     10         9
# 2             1         1       999  ...       2       2      9         5
# 3             7         1       999  ...       2       2      9         9
# 4             1         1       999  ...       2       2      8         1
# ...         ...       ...       ...  ...     ...     ...    ...       ...
# 809649       11         1       999  ...       2       2      5         9
# 809650        4         1       999  ...       9       2      5         1
# 809651        7         1       999  ...       9       2      5         9
# 809652        7         1       999  ...       9       2      5         9
# 809653       11         1       999  ...       9       2      5         3
#
#         SEXP  TENURP  TOTINCP  UNITSP  VALUEP  WKSWKP
# 0          1       1        3       4       0       0
# 1          1       1       88       4       0      88
# 2          2       1        5       5       0       0
# 3          1       1       88       5       0      88
# 4          2       1        2       4       0      88
# ...      ...     ...      ...     ...     ...     ...
# 809649     1       1       88       7       1      88
# 809650     1       2        1       4      88      88
# 809651     2       2       88       4      88      88
# 809652     2       2       88       4      88      88
# 809653     1       2        3       3      88       1
#
# [809654 rows x 41 columns]

# %%
def analyze_feature_value(dataset, feature):
    """Return weighted count of negative and positive language shifts for a value."""
    
    weight_name = 'WEIGHTP' if 'WEIGHTP' in dataset else 'WEIGHT'
    
    sums = dataset[['LanguageShift', weight_name, feature]].groupby([feature], as_index=False).sum()
    
    sums_dict = dict(zip(sums[feature], sums[weight_name]))
    
    pd.options.display.float_format = '{:.2f}'.format
    analyzed = dataset[[weight_name, 'LanguageShift', feature]].groupby([feature, 'LanguageShift'], as_index=False).sum()
    
    analyzed[weight_name] = [weight / sums_dict[value] for weight, value in zip(analyzed[weight_name], analyzed[feature])]
    
    return analyzed.loc[analyzed['LanguageShift'] == True]


analyze_feature_value(shift_1991, 'SEXP')
# Out:
#    SEXP  LanguageShift  WEIGHTP
# 1     1           True     0.07
# 3     2           True     0.08

# %% [markdown]
# ## 2016 Full Feature List
#
# ```
# Via Katie:
#
#
# in analysis:
# a comparison of langShift== true/langShift==False and ages of respondents [ theory: more young respondents in our data, leaving less time for language shift to occur, leaving imbalance in data towards languageShift == False]
# a comparison of genstat and langShift [ theory: more genstat ==1 (ie. first gen immigrants) in sample, means more langshift == false]
#
#
# Analyze generation status and age of immigration and age in general
#
# Language shift correlates with many fields which correlate with wealth!
# * E.g. Highest_Education_Location_vs_Residence
#
# Immigration status and Aboriginal status matter little, but immigrant generation, group, Aboriginal group, etc. matter much more; this may be due to the dropping of certain fields, which was done in the plain 2016 but not the comparisons
#
# Mother's place of birth matters much more than father's
# ```

# %% [markdown]
# ### Age and Generation Status
#
# Language shift is highest for second generation immigrants with both parents born outside of Canada.  It is very low for third generation immigrants.
#
# Language shifts are more common in immigrants 25-49, and again at 80 and up.

# %%
analyze_feature_value(shift_2016_all, 'GENSTAT')
# Out:
#    GENSTAT  LanguageShift  WEIGHT
# 1        1           True    0.32
# 3        2           True    0.48
# 5        3           True    0.22
# 7        4           True    0.02
# 9        8           True    0.27

# %%
analyze_feature_value(shift_2016_all, 'AGEGRP')
# Out:
#     AGEGRP  LanguageShift  WEIGHT
# 1        1           True    0.09
# 3        2           True    0.12
# 5        3           True    0.13
# 7        4           True    0.16
# 9        5           True    0.16
# 11       6           True    0.18
# 13       7           True    0.17
# 15       8           True    0.19
# 17       9           True    0.22
# 19      10           True    0.22
# 21      11           True    0.21
# 23      12           True    0.22
# 25      13           True    0.22
# 27      14           True    0.20
# 29      15           True    0.19
# 31      16           True    0.18
# 33      17           True    0.18
# 35      18           True    0.18
# 37      19           True    0.20
# 39      20           True    0.22
# 41      21           True    0.24
# 43      88           True    0.28

# %% [markdown]
# ### Inequality Related Fields
#
# * LICO: No insight
# * HHInc: Higher with low income households and high income households
# * WRKACT: Higher with part time work except for the highest week bracket
# * REPAIR: No insight
# * ROOMS: Highest for households with few rooms
# * SHELCO: Highest for high shelter costs
# * LOC_ST_RES: High for students not living in the same province as their school
# * HHMRKINC: Highest for high market income households

# %%
analyze_feature_value(shift_2016_all, 'LICO')
# Out:
#    LICO  LanguageShift  WEIGHT
# 1     1           True    0.19
# 3     2           True    0.19
# 5     8           True    0.31
# 7     9           True    0.29

# %%
analyze_feature_value(shift_2016_all, 'HHInc')
# Out:
#     HHInc  LanguageShift  WEIGHT
# 1       1           True    0.20
# 3       2           True    0.21
# 5       3           True    0.22
# 7       4           True    0.18
# 9       5           True    0.18
# 11      6           True    0.16
# 13      7           True    0.18
# 15      8           True    0.15
# 17      9           True    0.17
# 19     10           True    0.17
# 21     11           True    0.17
# 23     12           True    0.17
# 25     13           True    0.17
# 27     14           True    0.17
# 29     15           True    0.17
# 31     16           True    0.18
# 33     17           True    0.17
# 35     18           True    0.17
# 37     19           True    0.17
# 39     20           True    0.18
# 41     21           True    0.18
# 43     22           True    0.17
# 45     23           True    0.18
# 47     24           True    0.17
# 49     25           True    0.19
# 51     26           True    0.19
# 53     27           True    0.20
# 55     28           True    0.20
# 57     29           True    0.21
# 59     30           True    0.22
# 61     31           True    0.24
# 63     32           True    0.26
# 65     33           True    0.31
# 67     88           True    0.31

# %%
analyze_feature_value(shift_2016_all, 'WRKACT')
# Out:
#     WRKACT  LanguageShift  WEIGHT
# 1        1           True    0.19
# 3        2           True    0.21
# 5        3           True    0.19
# 7        4           True    0.21
# 9        5           True    0.18
# 11       6           True    0.21
# 13       7           True    0.18
# 15       8           True    0.20
# 17       9           True    0.19
# 19      10           True    0.20
# 21      11           True    0.22
# 23      12           True    0.19
# 25      88           True    0.20
# 27      99           True    0.13

# %%
analyze_feature_value(shift_2016_all, 'REPAIR')
# Out:
#    REPAIR  LanguageShift  WEIGHT
# 1       1           True    0.20
# 3       2           True    0.18
# 5       3           True    0.19
# 7       8           True    0.33

# %%
analyze_feature_value(shift_2016_all, 'ROOMS')
# Out:
#     ROOMS  LanguageShift  WEIGHT
# 1       1           True    0.29
# 3       2           True    0.26
# 5       3           True    0.21
# 7       4           True    0.17
# 9       5           True    0.17
# 11      6           True    0.19
# 13      7           True    0.19
# 15      8           True    0.19
# 17      9           True    0.19
# 19     10           True    0.20
# 21     11           True    0.23
# 23     88           True    0.28

# %%
analyze_feature_value(shift_2016_all, 'SHELCO')
# Out:
#     SHELCO  LanguageShift  WEIGHT
# 1        0           True    0.14
# 3        1           True    0.17
# 5        2           True    0.18
# 7        3           True    0.17
# 9        4           True    0.16
# 11       5           True    0.17
# 13       6           True    0.19
# 15       7           True    0.22
# 17       8           True    0.24
# 19       9           True    0.27

# %%
analyze_feature_value(shift_2016_all, 'LOC_ST_RES')
# Out:
#    LOC_ST_RES  LanguageShift  WEIGHT
# 1           1           True    0.19
# 3           2           True    0.29
# 5           3           True    0.27
# 7           4           True    0.18
# 9           9           True    0.13

# %%
analyze_feature_value(shift_2016_all, 'HHMRKINC')
# Out:
#     HHMRKINC  LanguageShift  WEIGHT
# 1          1           True    0.15
# 3          2           True    0.19
# 5          3           True    0.18
# 7          4           True    0.19
# 9          5           True    0.19
# 11         6           True    0.18
# 13         7           True    0.19
# 15         8           True    0.17
# 17         9           True    0.17
# 19        10           True    0.17
# 21        11           True    0.17
# 23        12           True    0.17
# 25        13           True    0.17
# 27        14           True    0.17
# 29        15           True    0.16
# 31        16           True    0.17
# 33        17           True    0.17
# 35        18           True    0.18
# 37        19           True    0.18
# 39        20           True    0.18
# 41        21           True    0.17
# 43        22           True    0.19
# 45        23           True    0.20
# 47        24           True    0.19
# 49        25           True    0.20
# 51        26           True    0.20
# 53        27           True    0.20
# 55        28           True    0.22
# 57        29           True    0.22
# 59        30           True    0.23
# 61        31           True    0.25
# 63        32           True    0.27
# 65        33           True    0.31
# 67        88           True    0.31

# %% [markdown]
# ### Binary vs Detailed Fields
#
# Immigrants who landed before 1980 swings IMMCAT5 massively.
#
# Métis especially, and Inuit rarely shift.

# %%
analyze_feature_value(shift_2016_all, 'IMMCAT5')
# Out:
#     IMMCAT5  LanguageShift  WEIGHT
# 1         1           True    0.10
# 3         2           True    0.52
# 5         3           True    0.28
# 7        21           True    0.28
# 9        22           True    0.26
# 11       23           True    0.26
# 13       88           True    0.34

# %%
analyze_feature_value(shift_2016_all, 'IMMSTAT')
# Out:
#    IMMSTAT  LanguageShift  WEIGHT
# 1        1           True    0.10
# 3        2           True    0.32
# 5        3           True    0.28
# 7        8           True    0.34

# %%
analyze_feature_value(shift_2016_all, 'BFNMEMB')
# Out:
#    BFNMEMB  LanguageShift  WEIGHT
# 1        0           True    0.19
# 3        1           True    0.34

# %%
analyze_feature_value(shift_2016_all, 'ABOID')
# Out:
#     ABOID  LanguageShift  WEIGHT
# 1       1           True    0.31
# 3       2           True    0.03
# 5       3           True    0.18
# 7       4           True    0.06
# 9       5           True    0.10
# 11      6           True    0.19

# %% [markdown]
# ### Sex and Parental Sex
#
# No need to examine categories, but do note how mother matters more.  Linkt he source related to mothers.

# %%
analyze_feature_value(shift_2016_all, 'Sex')
# Out:
#    Sex  LanguageShift  WEIGHT
# 1    1           True    0.19
# 3    2           True    0.19

# %%
analyze_feature_value(shift_2016_all, 'POBM')
# Out:
#     POBM  LanguageShift  WEIGHT
# 1      1           True    0.03
# 3      2           True    0.32
# 5      3           True    0.53
# 7      4           True    0.22
# 9      5           True    0.27
# 11     6           True    0.29
# 13     8           True    0.43

# %%
analyze_feature_value(shift_2016_all, 'POBF')
# Out:
#     POBF  LanguageShift  WEIGHT
# 1      1           True    0.03
# 3      2           True    0.31
# 5      3           True    0.52
# 7      4           True    0.22
# 9      5           True    0.27
# 11     6           True    0.29
# 13     8           True    0.43

# %% [markdown]
# ---
#
# ## 1991 vs 2016 Comparisons
#
# ```
# Canadian citizenship status matters much more in 1991
#
# Property value matter much more in 2016
#
# Highest degree and secondary degree matters more in 2016, while highest attended matters more in 1991
#
# Field of study matters much more in 2016
# ```

# %% [markdown]
# ### Citizenship
#
# Canadian citizens by birth do not typically change their language.  Adding the country of birth, with Canada as a country of birth, was very significant!

# %%
analyze_feature_value(shift_1991, 'CITIZENP')
# Out:
#    CITIZENP  LanguageShift  WEIGHTP
# 1         1           True     0.04
# 3         2           True     0.30
# 5         3           True     0.15
# 7         4           True     0.19
# 9         8           True     0.26

# %%
analyze_feature_value(shift_2016, 'Citizen')
# Out:
#    Citizen  LanguageShift  WEIGHT
# 1        1           True    0.04
# 3        2           True    0.28
# 5        3           True    0.21

# %% [markdown]
# ### Property Value
#
# The effect is far more pronounced in the 2016 version at higher end, but not at lower end.

# %%
analyze_feature_value(shift_1991, 'VALUEP')
# Out:
#     VALUEP  LanguageShift  WEIGHTP
# 1        0           True     0.04
# 3        1           True     0.05
# 5        2           True     0.05
# 7        3           True     0.07
# 9        4           True     0.09
# 11       5           True     0.14
# 13       6           True     0.12
# 15      88           True     0.06

# %%
analyze_feature_value(shift_2016, 'VALUE')
# Out:
#     VALUE  LanguageShift  WEIGHT
# 1       0           True    0.04
# 3       1           True    0.05
# 5       2           True    0.07
# 7       3           True    0.09
# 9       4           True    0.11
# 11      5           True    0.13
# 13      6           True    0.15
# 15      7           True    0.17
# 17     88           True    0.10

# %% [markdown]
# ### Degrees vs Attendance
#
# Higher level degrees cause more shifts in 2016 - maybe due to more foreign academia?  2016 adding in postsecondary with secondary adds to this hypothesis.
#
# Very interesting - doctorates and masters are lumped in with university in 2016 and it is LESS important.  Maybe that is the metric all along?

# %%
analyze_feature_value(shift_1991, 'DGREEP')
# Out:
#     DGREEP  LanguageShift  WEIGHTP
# 1        1           True     0.08
# 3        2           True     0.07
# 5        3           True     0.10
# 7        4           True     0.09
# 9        5           True     0.09
# 11       6           True     0.10
# 13       7           True     0.11
# 15       8           True     0.13
# 17       9           True     0.13
# 19      10           True     0.16
# 21      98           True     0.33
# 23      99           True     0.03

# %%
analyze_feature_value(shift_2016, 'HDGREE')
# Out:
#     HDGREE  LanguageShift  WEIGHT
# 1        1           True    0.09
# 3        2           True    0.08
# 5        3           True    0.07
# 7        4           True    0.08
# 9        5           True    0.08
# 11       6           True    0.08
# 13       7           True    0.10
# 15       8           True    0.12
# 17       9           True    0.13
# 19      10           True    0.14
# 21      11           True    0.16
# 23      12           True    0.15
# 25      13           True    0.17
# 27      88           True    0.17
# 29      99           True    0.07

# %%
analyze_feature_value(shift_1991, 'SECGRADP')
# Out:
#     SECGRADP  LanguageShift  WEIGHTP
# 1          1           True     0.08
# 3          2           True     0.11
# 5          3           True     0.09
# 7          4           True     0.07
# 9          5           True     0.10
# 11         9           True     0.03

# %%
analyze_feature_value(shift_2016, 'SSGRAD')
# Out:
#     SSGRAD  LanguageShift  WEIGHT
# 1        1           True    0.09
# 3        2           True    0.09
# 5        3           True    0.08
# 7        4           True    0.08
# 9        5           True    0.07
# 11       6           True    0.09
# 13       7           True    0.12
# 15       8           True    0.13
# 17       9           True    0.14
# 19      10           True    0.16
# 21      11           True    0.15
# 23      12           True    0.17
# 25      88           True    0.17
# 27      99           True    0.07

# %%
analyze_feature_value(shift_1991, 'HLOSP')
# Out:
#     HLOSP  LanguageShift  WEIGHTP
# 1       1           True     0.08
# 3       2           True     0.10
# 5       3           True     0.07
# 7       4           True     0.07
# 9       5           True     0.08
# 11      6           True     0.09
# 13      7           True     0.11
# 15      8           True     0.09
# 17      9           True     0.09
# 19     10           True     0.10
# 21     11           True     0.11
# 23     12           True     0.11
# 25     13           True     0.13
# 27     14           True     0.16
# 29     98           True     0.33
# 31     99           True     0.03

# %%
analyze_feature_value(shift_2016, 'ATTSCH')
# Out:
#     ATTSCH  LanguageShift  WEIGHT
# 1        1           True    0.10
# 3        2           True    0.08
# 5        3           True    0.10
# 7        4           True    0.13
# 9        5           True    0.13
# 11       8           True    0.13
# 13       9           True    0.07

# %% [markdown]
# ### Field of Study
#
# No clearly discernable patterns other than STEM fields being really high shift-wise.  Maybe many STEM majors are foreign born?

# %%
analyze_feature_value(shift_1991, 'DGMFSP')
# Out:
#     DGMFSP  LanguageShift  WEIGHTP
# 1        1           True     0.08
# 3        2           True     0.11
# 5        3           True     0.09
# 7        4           True     0.09
# 9        5           True     0.11
# 11       6           True     0.08
# 13       7           True     0.12
# 15       8           True     0.16
# 17       9           True     0.10
# 19      10           True     0.08
# 21      11           True     0.11
# 23      12           True     0.13
# 25      13           True     0.06
# 27      14           True     0.08
# 29      99           True     0.03

# %%
analyze_feature_value(shift_2016, 'CIP2011')
# Out:
#     CIP2011  LanguageShift  WEIGHT
# 1         1           True    0.09
# 3         2           True    0.10
# 5         3           True    0.11
# 7         4           True    0.12
# 9         5           True    0.12
# 11        6           True    0.14
# 13        7           True    0.15
# 15        8           True    0.10
# 17        9           True    0.06
# 19       10           True    0.10
# 21       11           True    0.07
# 23       13           True    0.08
# 25       88           True    0.14
# 27       99           True    0.07
